# %% [markdown]
# ## Data Wrangling with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('data/media.csv')
df
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 0             0      76  The Democratic Unionist party cannot be allowe...
# 1             1      77   Chas Hodges, of the musical duo Chas and Dave...
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 0              3  2018-09-23 23:33:02
# 1              3  2018-09-23 23:33:23
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [240 rows x 5 columns]

# %% [markdown]
# ### Dropping elements in a DataFrame

# %% [markdown]
# If we want to get rid of specific elements in a DataFrame, we can use the drop command:

# %%
df.drop([0, 1])
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# 5             5      81  At least 29 people, including children, have b...
# 6             6      82  Thousands of people marched to Whitehall on Sa...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# 5              3  2018-09-23 23:33:40
# 6              3  2018-09-23 23:33:43
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [238 rows x 5 columns]

# %% [markdown]
# As you can see, we passed along a list of elements we want to drop, in this case integer values. This means, we effectively remove the first two rows in the DataFrame. However, if we print the content of the DataFrame again, the following happens:

# %%
df
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 0             0      76  The Democratic Unionist party cannot be allowe...
# 1             1      77   Chas Hodges, of the musical duo Chas and Dave...
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 0              3  2018-09-23 23:33:02
# 1              3  2018-09-23 23:33:23
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [240 rows x 5 columns]

# %% [markdown]
# So, the rows are basically still in place. We have two options here, one is, to assign the result of the drop-operation to a new variable:

# %%
df_new = df.drop([0, 1])
df_new
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# 5             5      81  At least 29 people, including children, have b...
# 6             6      82  Thousands of people marched to Whitehall on Sa...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# 5              3  2018-09-23 23:33:40
# 6              3  2018-09-23 23:33:43
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [238 rows x 5 columns]

# %% [markdown]
# That seems to work. The other is, to make use of the __inplace__ parameter:

# %%
df.drop([0, 1], inplace=True)
df
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# 5             5      81  At least 29 people, including children, have b...
# 6             6      82  Thousands of people marched to Whitehall on Sa...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# 5              3  2018-09-23 23:33:40
# 6              3  2018-09-23 23:33:43
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [238 rows x 5 columns]

# %% [markdown]
# Works well - but notice the following:
# <div class="alert alert-block alert-warning">
# <b>Tip:</b> If you use this repeatedly, e.g. while reworking your code, the cached DataFrame may have already lost its content and you need to refresh the cells before. Otherwise, this results in an error message.
# </div>

# %% [markdown]
# Dropping/removing columns works similar except for the fact that you have to change the orientation of the elements to be dropped - use the ax is parameter as in the following example to achieve this:

# %%
df.drop('Unnamed: 0', axis=1)
# Out:
#      art_id                                        art_content  art_comment  \
# 2        78  T he official theme of this year’s UN general ...            3
# 3        79  Dawn Butler has spoken approvingly about Labou...            3
# 4        80  Drug producers are capitalising on the rise of...            9
# 5        81  At least 29 people, including children, have b...            3
# 6        82  Thousands of people marched to Whitehall on Sa...            3
# ..      ...                                                ...          ...
# 235    1302  Theresa May will come under intense pressure f...            3
# 236    1303  Senior allies of Jeremy Corbyn questioned the ...            3
# 237    1304  A man in his 80s has been arrested on suspicio...            3
# 238    1305  A year ago, the Labour party conference in Bri...            9
# 239    1306  Labour has confirmed that its one-day music an...            3
#
#         art_date_grabbed
# 2    2018-09-23 23:33:27
# 3    2018-09-23 23:33:30
# 4    2018-09-23 23:33:37
# 5    2018-09-23 23:33:40
# 6    2018-09-23 23:33:43
# ..                   ...
# 235  2018-09-23 23:51:59
# 236  2018-09-23 23:52:06
# 237  2018-09-23 23:52:09
# 238  2018-09-23 23:52:12
# 239  2018-09-23 23:52:19
#
# [238 rows x 4 columns]

# %% [markdown]
# Dropping a row if a certain value is not found can be achieved like this:

# %%
df[df.art_comment == 9]
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 4             4      80  Drug producers are capitalising on the rise of...
# 10           10      86                                                NaN
# 11           11      87  When the southern Italian city of Matera found...
# 12           12      88    Heidi Stephens   Sat 22 Sep 2018 20.36 BST  ...
# 13           13      89  B orn in West Yorkshire ,  Jodie Whittaker , 3...
# ..          ...     ...                                                ...
# 214         214    1227  Alexandre Lacazette scored a beauty, Pierre-Em...
# 216         216    1229  The match had been billed as the battle of the...
# 217         217    1230  This 80-minute performance was a microcosm of ...
# 231         231    1286  Rockney was the name given to the fusion of vi...
# 238         238    1305  A year ago, the Labour party conference in Bri...
#
#      art_comment     art_date_grabbed
# 4              9  2018-09-23 23:33:37
# 10             9  2018-09-23 23:34:04
# 11             9  2018-09-23 23:34:08
# 12             9  2018-09-23 23:34:11
# 13             9  2018-09-23 23:34:19
# ..           ...                  ...
# 214            9  2018-09-23 23:50:44
# 216            9  2018-09-23 23:50:49
# 217            9  2018-09-23 23:50:55
# 231            9  2018-09-23 23:51:45
# 238            9  2018-09-23 23:52:12
#
# [80 rows x 5 columns]

# %% [markdown]
# Conversely, we remove all the rows if a certain string is missing:

# %%
res = df[df.art_id == 86]
type(res)
# Out:
# pandas.core.frame.DataFrame

# %%
df[pd.np.nan != df.art_content]
# Out:
#      Unnamed: 0  art_id                                        art_content  \
# 2             2      78  T he official theme of this year’s UN general ...
# 3             3      79  Dawn Butler has spoken approvingly about Labou...
# 4             4      80  Drug producers are capitalising on the rise of...
# 5             5      81  At least 29 people, including children, have b...
# 6             6      82  Thousands of people marched to Whitehall on Sa...
# ..          ...     ...                                                ...
# 235         235    1302  Theresa May will come under intense pressure f...
# 236         236    1303  Senior allies of Jeremy Corbyn questioned the ...
# 237         237    1304  A man in his 80s has been arrested on suspicio...
# 238         238    1305  A year ago, the Labour party conference in Bri...
# 239         239    1306  Labour has confirmed that its one-day music an...
#
#      art_comment     art_date_grabbed
# 2              3  2018-09-23 23:33:27
# 3              3  2018-09-23 23:33:30
# 4              9  2018-09-23 23:33:37
# 5              3  2018-09-23 23:33:40
# 6              3  2018-09-23 23:33:43
# ..           ...                  ...
# 235            3  2018-09-23 23:51:59
# 236            3  2018-09-23 23:52:06
# 237            3  2018-09-23 23:52:09
# 238            9  2018-09-23 23:52:12
# 239            3  2018-09-23 23:52:19
#
# [238 rows x 5 columns]
